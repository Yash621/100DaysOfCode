# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import seaborn as sns


rating =pd.read_csv("https://raw.githubusercontent.com/codeforcauseorg/ML-Bootcamp-July/master/datasets/recom/rating.csv")

# %%
rating.head()
# Out:
#    Unnamed: 0  user_id  anime_id  rating
# 0     2443027    23306      3503       7
# 1     4751250    45366      1190      -1
# 2     7694962    72305      5150       8
# 3     7066179    65975      6045      10
# 4     7198178    67151      3702       9

# %%
rating.shape
# Out:
# (3906868, 4)

# %%
anime=pd.read_csv("./anime.csv")
anime.genre
genres=np.array(anime.genre)

# %%
anime.shape
# Out:
# (12294, 7)

# %%
vals=[("Drama" in str(genre)) for genre in genres ]

# %%
X=anime.loc[vals]
X.shape
# Out:
# (2016, 7)

# %%
X_mod=X[["episodes","rating","members"]]
X_mod
# Out:
#       episodes  rating  members
# 0            1    9.37   200630
# 1           64    9.26   793665
# 5           10    9.15    93351
# 7          110    9.11    80679
# 10          24    9.06   456749
# ...        ...     ...      ...
# 12017        1    5.72     4981
# 12071        3    5.61      654
# 12143        1    5.46      841
# 12203        2    5.23     4550
# 12252  Unknown     NaN     2459
#
# [2016 rows x 3 columns]

# %%
sns.scatterplot(X_mod.rating,X_mod.members)
# Out:
# /home/yash/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='rating', ylabel='members'>

# %%
sns.scatterplot(X.rating,X.type)
# Out:
# /home/yash/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='rating', ylabel='type'>

# %%
sns.scatterplot(X.rating,X.episodes)
# Out:
# /home/yash/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='rating', ylabel='episodes'>
